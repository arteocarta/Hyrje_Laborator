# %% [markdown]
# ## Laboratori 4 - Pse përdorim Python në laborator?
#
# **Kursi:** Hyrje në laborator (Fizikë & Shkenca Kompjuterike)
# **Studenti:** *Arteo Carta*
# **Data:** *11-06-2026*
#
# Puna e zakonshme në laborator kërkon që:
#
# -   të përpunojmë **matjet e marra nga eksperimentet**
# -   t'i paraqesim rezultatet në **formë grafike**
# -   të testojmë **modele matematikore** mbi të dhënat reale
# -   të nxjerrim **vlera numerike përfundimtare**
#
# Python e bën këtë proces shumë më të lehtë, sepse:
#
# -   ka një sintaksë **të lexueshme dhe të shkurtër**
# -   ofron një ekosistem të pasur bibliotekash shkencore
# -   është bërë gjuha standarde e punës në **fizikë, inxhinieri dhe shkenca të tjera**
#
# Bibliotekat bazë që do të na duhen gjatë kursit:
#
# | Biblioteka     | Përdorimi                              |
# | -------------- | -------------------------------------- |
# | **NumPy**      | vargje numerike dhe veprime me vektorë |
# | **Matplotlib** | ndërtimi i grafikëve                   |
# | **SciPy**      | metoda numerike dhe përshtatje modelesh |

# %% [markdown]
# # 2. Struktura e një programi në Notebook
#
# Një program në notebook ndahet në qeliza që ekzekutohen një nga një. Më poshtë jepet një shembull i shkurtër:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0,1,2,3])
y = np.array([0,1,8,27])

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 3. Variablat
# Një variabël lidh një emër me një vlerë në kujtesë, e cila mund të ripërdoret në llogaritje.

# %%
p = 12
q = 5
shuma = p + q

print(shuma)
# Out:
# 17

# %% [markdown]
# # 4. Listat dhe vektorët
#
# ### Lista në Python

# %%
values = [4,8,12,16]

# %%
import numpy as np

values = np.array([4,8,12,16])

# %%
values / 2
# Out:
# array([2., 4., 6., 8.])
