# %% [markdown]
# ## Laboratori 02 – Struktura e Raportit dhe Markdown
#
# **Studenti:** *Arteo Carta*
# **Data:** *2026-06-11*
#
# ---
#
# ## Qëllimi
#
# 1. Të praktikoni shkrimin profesional në **Markdown**.
# 2. Të përdorni **formula matematikore (LaTeX)**.
# 3. Të ndërtoni **strukturën standarde** të raportit laboratorik në notebook.
#
# > Ky laborator nuk kërkon ende analiza të avancuara. Fokus: dokumentim, strukturë, qartësi.
#
# ---
#
# ## Rregulla cilësie
#
# - Çdo madhësi fizike shoqërohet me **njësi**.
# - Çdo figurë ka **titull/etiketa** dhe përshkrim.
# - Çdo tabelë ka **kokë** dhe njësi.

# %% [markdown]
# ## 1. Titulli dhe Qëllimi
#
# Shkruani objektivin e eksperimentit (2–4 fjali).
# **Shembull:** “Të matet diametri i një cilindri me mjete të ndryshme dhe të vlerësohet pasiguria e matjes.”
#
# **Qëllimi (plotësoni):**
# - Eksperimenti ka si qëllim përcaktimin e densitetit të ujit nëpërmjet matjes së masës dhe vëllimit të tij me mjete laboratorike bazë. Gjatë procesit synohet gjithashtu vlerësimi i saktësisë së matjeve dhe kuptimi i burimeve të pasiguria eksperimentale.

# %% [markdown]
# ## 2. Baza teorike
#
# Shkruani formulat dhe shpjegoni simbolet.
#
# **Shembull (vëllimi i cilindrit):**
# $$
# V = \pi r^2 h
# $$
#
# ku:
# - $r$ – rrezja (m)
# - $h$ – lartësia (m)
# - $V$ – vëllimi (m$^3$)
#
# **Teoria (plotësoni):**
# $$
#  \rho =\frac{m}{V}
# $$
#
# ku:
# - $\rho$ – densiteti i lëngut (kg/m$^3$)
# - $m$ – masa e lëngut (kg)
# - $V$ – vëllimi i lëngut (m$^3$)

# %% [markdown]
# ## 3. Aparatura dhe procedura
#
# Lista e instrumenteve dhe hapat kryesorë.
#
# **Aparatura (plotësoni):**
# - Peshore laboratorike me saktësi të lartë
# - Cilindër matës graduik / Enë matëse / Termometër / Ujë i distiluar / Fletë shënimesh
#
# **Procedura (plotësoni, 5–8 hapa):**
# 1. Vendoset gjithë aparatura në mënyrë të rregullt në tavolininë e laboratorit.
# 2. Peshohet ena e zbrazët dhe shënohet masa e saj fillestare.
# 3. Hidhet një sasi e caktuar uji brenda enës dhe matet masa e re totale.
# 4. Gjendet masa e saktë e ujit duke zbritur masën e enës nga totali.
# 5. Lexohet vëllimi i ujit direkt nga cilindëri matës duke shmangur parallaksin.
# 6. Regjistrohen me kujdes të dhënat: masa, vëllimi dhe temperatura e ujit.
# 7. Aplikohet formula e densitetit për llogaritjen e rezultatit.
# 8. Bëhet vlerësimi i pasigurisë duke marrë parasysh kufijtë e saktësisë së instrumenteve.

# %% [markdown]
# ## 4. Të dhënat bruto (raw data)
#
# Vendosni të dhënat në tabelë, me njësi.
#
# | Matja | Masa \(m\) (g) | Vëllimi \(V\) (ml) | Temperatura (°C) | Koment |
# |------:|---------------:|--------------------:|-----------------:|--------|
# | 1     | 50.2           | 50                 | 22               | Matje e parë |
# | 2     | 100.5          | 100                | 22               | Matje e dytë |
# | 3     | 150.7          | 150                | 22               | Matje e tretë |
# | 4     | 200.9          | 200                | 22               | Matje e katërt |
#
#
# > Këtu nuk bëhet analizë. Vetëm të dhënat.

# %% [markdown]
# ## 5. Figura (opsionale)
#
# Nëse keni foto/skica të setup-it, vendosini në repository (p.sh. në `figs/`) dhe referojini.
#
# Shembull:
# ```markdown
# ![Skema e setup-it](figs/setup.png)
# ```
#
# **Figura (plotësoni):**
# ![Skema e setup-it](https://copilot.microsoft.com/th/id/BCO.eab6bd48-453c-4346-ab42-723d4ffdcb9a.png)

# %% [markdown]
# ## 6. Analiza (fillestare)
#
# Në këtë javë mjafton të përshkruani çfarë do të analizoni javën tjetër:
#
# - Cila madhësi do të llogaritet?
# - Çfarë grafiku do të prodhohet?
# - Cilat janë burimet kryesore të pasigurisë?
#
# **Analiza (plotësoni):**
# - Madhësia kryesore që do të llogaritet është densiteti i ujit ($\rho = m/V$), ku $m$ është masa dhe $V$ vëllimi i matur eksperimentalisht.
# - Do të ndërtohet grafiku i masës në funksion të vëllimit; koefiqenti i drejtëzës korrespondon me densitetin e ujit.
# - Burimet kryesore të pasigurisë përfshijnë:
#   - Rezolucionin e peshoreve laboratorike
#   - Graduimin e cilindërit matës dhe efektin e meniskut
#   - Luhatjet e temperaturës, të cilat ndikojnë në densitetin teorik të ujit

# %% [markdown]
# ## 7. Diskutimi dhe përfundimi
#
# **Diskutimi (plotësoni):**
# - A ishin matjet të qëndrueshme?
# - A pati vështirësi në leximin e shkallës?
# - Çfarë do të përmirësonit herën tjetër?
#
# **Përfundimi (plotësoni, 3–5 fjali):**
# - Rezultatet e matjeve treguan qëndrueshmëri të mirë, pasi raporti masë/vëllim u ruajt pothuajse konstant në të gjitha përpëritjet.
# - Leximi i cilindërit matës ishte i menaxhuëshëm, por meniskut i ujit i kushtoi vëmendje e veçantë për të shmangur gabimet sistematike.
# - Për eksperimentet e ardhshme, do të ishte e dobishme përdorimi i peshoreve me ndjeshmëri më të lartë dhe cilindërave me graduim më të hollë, si dhe stabilizimi i kushteve termike të ambientit për rezultate më të sakta.

# %%
# (Opsionale) Qelizë testuese për të parë që Python funksionon edhe këtu.
# Nuk kërkohet analizë numerike në këtë javë.
print("Notebook-u është gati për raport laboratorik.")
# Out:
# Notebook-u është gati për raport laboratorik.
